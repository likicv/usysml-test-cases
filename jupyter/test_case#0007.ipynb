# %%
package PackageVehicles {
  
    part def Vehicle;
    part def Wheel;

    part vehicle:Vehicle {
        part w:Wheel[4];
    }
}
# Out:
# Package PackageVehicles (1995a2c0-541a-4008-b73a-1a98c6cefc50)

# %%
%viz --view=tree PackageVehicles

# %%
package PackageVehicles {

    part def Vehicle;
    part def Wheel;

    part vehicle:Vehicle {
        part c;
        part w:Wheel;
    }
}
# Out:
# Package PackageVehicles (56e87fc8-7730-4d5e-b7da-ae7f1950ae61)

# %%
%viz --view=tree PackageVehicles

# %%
package PackageVehicles {
  
    part def Vehicle;
    part def Wheel;

    part vehicle:Vehicle {
        part w:Wheel;
    }
}
# Out:
# Package PackageVehicles (c53d4bee-cd78-48a7-a6b4-b1935d810e1a)

# %%
%viz --view=tree PackageVehicles

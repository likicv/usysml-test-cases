# %%
package PackageVehicles {
  
    part def Vehicle;
    part def Wheel;

    part vehicle:Vehicle {
        part w:Wheel;
    }
}

package PackageStations {
    part def VehicleStation;
}
# Out:
# Package PackageVehicles (df151346-4526-474b-9aad-86a78977503c)
# Package PackageStations (c4fff1fc-09b6-4f39-b5e4-a750cf593b4f)

# %%
%viz --view=tree PackageVehicles PackageStations

# %%
package PackageVehicles {
  
    part def Vehicle;
    part def Wheel;

    part vehicle:Vehicle {
        part w:Wheel;
    }
}
# Out:
# Package PackageVehicles (97f0a39a-9b4e-44e8-a694-abc0f7a8ef6b)

# %%
%viz --view=tree PackageVehicles

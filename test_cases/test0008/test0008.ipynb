# %%
package PackageVehicles {

    part def Vehicle;
    part def Wheel;
    part partnotype1;

    part vehicle:Vehicle {
        part w:Wheel[4];
        part partnotype2;
    }
}
# Out:
# Package PackageVehicles (4c5d9a4e-8e70-4efd-9328-27013aef3bdf)

# %%
%viz --view=tree PackageVehicles
